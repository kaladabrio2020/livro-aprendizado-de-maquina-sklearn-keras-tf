# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('dataset/Polinomial.csv')
X = data['x']
Y = data['y']

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing   import PolynomialFeatures
from sklearn.linear_model    import LinearRegression,SGDRegressor

# %%
plt.scatter(X,Y)
plt.show()

# %%
X = PolynomialFeatures(degree=2,include_bias=False).fit_transform(X.values.reshape(-1,1))

# %%
xtrain ,xtest ,ytrain ,ytest = train_test_split(X,Y,train_size=30,random_state=42)

# %%
reg = LinearRegression()
reg.fit(xtrain,ytrain)


predreg = reg.predict(xtest)
# Out:
# array([ 496.39372938,  326.54210756,  278.1882319 , 1037.32248352,
#          18.98554287,  157.91659976, 2296.38829775, 1131.12468306,
#        2579.02101036,   28.92831225])

# %%
plt.scatter(xtrain[:,0],ytrain)
plt.plot(sorted(xtest[:,0]),sorted(predreg))
plt.show()
