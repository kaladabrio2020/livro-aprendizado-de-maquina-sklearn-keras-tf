# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
X ,y = make_regression(n_samples=1000, n_features=1, random_state=42 ,noise=5)
xtrain ,xtest ,ytrain ,ytest = train_test_split(X ,y ,random_state=42 ,test_size=0.2)

# %%
plt.scatter(xtrain,ytrain)
plt.show()

# %% [markdown]
# &nbsp;

# %% [markdown]
# ### Regressão Linear

# %%
linearReg = LinearRegression()
linearReg.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %%
linearReg.coef_ ,linearReg.intercept_
# Out:
# (array([16.73239485]), -0.04625051348556339)

# %%
plt.scatter(xtrain, ytrain)
plt.plot(xtrain,  xtrain*linearReg.coef_+ linearReg.intercept_, c='red')
plt.show()

# %%
# Out:
# array([[0.],
#        [0.]])
